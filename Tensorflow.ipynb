# %% [markdown]
# <a href="https://colab.research.google.com/github/fafa20252025/fariba/blob/main/Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
boston=pd.read_csv("Boston.csv")
boston.head()
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2

# %%
boston.shape
# Out:
# (506, 15)

# %% [markdown]
# #Dataset description: input the link of dataset
# #Explanatory data analysis: you need to do this

# %%
y=boston["medv"]  #Target variable
x=boston.drop(["medv", "Unnamed: 0"],axis=1) #independent variable, dropping Unnamed: 0 column

# %%
x.shape
y.shape
# Out:
# (506,)

# %% [markdown]
# #Train Test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (339, 13)
# (167, 13)
# (339,)
# (167,)

# %% [markdown]
# #Model building in Tensorflow (Neural Network)
#
#  3 steps to follow
#   1-Model definition
#     -Define architecture of the model ( number of layers, number of nodes, Activation functions)
#
# 2- Model compilation
#     -Optimisation algorithm , learning rate, cost function
#
# 3-Training
#     -number of iterations, dataset defining (test,train)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import Input # Corrected import for Input

model=Sequential()
model.add(Input(shape=(13,))) # Corrected: Use Input layer and shape as a tuple
model.add(Dense(units=1))   #this is our output layer.

# %% [markdown]
# we are going to have 13 wheightage as we have 13 inputs and one bias.

# %%
#Model compilation step

model.compile(optimizer="adam",loss="mean_squared_error")   #loss is know as cost function too

# %%
# Model training step

model.fit(x_train,y_train,epochs=100,validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9688.4258 - val_loss: 9001.4854
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8272.7930 - val_loss: 7722.5776
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6534.8657 - val_loss: 6672.5576
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5589.8945 - val_loss: 5844.5137
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5166.7188 - val_loss: 5217.3325
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4279.3921 - val_loss: 4745.7993
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4035.0322 - val_loss: 4394.0254
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3307.8877 - val_loss: 4131.7651
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3369.9470 - val_loss: 3926.6150
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3322.1892 - val_loss: 3764.7168
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2873.5803 - val_loss: 3628.1804
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2920.6545 - val_loss: 3502.1245
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2611.3464 - val_loss: 3387.3933
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2622.6265 - val_loss: 3275.6833
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2846.1582 - val_loss: 3166.1638
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2405.2512 - val_loss: 3061.7639
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2399.4473 - val_loss: 2958.4749
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2589.4858 - val_loss: 2854.1802
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2249.5315 - val_loss: 2754.5999
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2165.8752 - val_loss: 2658.5486
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2410.3940 - val_loss: 2562.2354
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1696.6460 - val_loss: 2473.0645
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1979.4283 - val_loss: 2378.4382
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2076.8918 - val_loss: 2288.2161
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1977.8951 - val_loss: 2205.5349
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1665.8853 - val_loss: 2121.5010
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1883.4220 - val_loss: 2037.4869
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1678.6841 - val_loss: 1957.5228
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1432.9310 - val_loss: 1884.2103
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1375.2513 - val_loss: 1809.5341
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1409.1758 - val_loss: 1739.3086
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1388.6924 - val_loss: 1670.3662
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1420.1273 - val_loss: 1604.4733
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 